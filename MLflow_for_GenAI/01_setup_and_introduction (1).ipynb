# %% [markdown]
# # Tutorial 1.1: Setup and Introduction
# - [source](https://github.com/dmatrix/mlflow-genai-tutorials/tree/main)
#
# ![](images/2_Notebook-11-Setup-and-Introduction.png)
#
# ## Getting Started with GenAI and MLflow
#
# This is the first notebook in the series. It walks through setting up your environment and getting oriented in the MLflow platform for GenAI development.
#
# ### What You'll Learn
# - What MLflow is and why it's useful for GenAI development
# - Core MLflow concepts and architecture
# - How to install and configure MLflow
# - How to start and access the MLflow UI
#
# ### Prerequisites
# - Python 3.9 or higher
# - pip or uv package manager
# - OpenAI API key (or other LLM provider credentials)
# - Basic understanding of Python and LLMs
#
# ### Estimated Time: 15-20 minutes

# %% [markdown]
# ---
# ## Step 1: What is MLflow?
#
# **MLflow** is an open-source platform for managing the end-to-end lifecycle of building and observing ML, GenAI, and LLM applications.
#
# ### Why MLflow for GenAI?
#
# 1. **Open source and vendor-neutral**: no lock-in to a specific cloud provider or LLM vendor
# 2. **OpenTelemetry compatible**: standard observability that fits your existing stack
# 3. **One platform**: tracking, tracing, evaluation, continuous monitoring, and deployment in one place
# 4. **30+ framework integrations**: OpenAI, LangChain, LlamaIndex, DSPy, AutoGen, and more
#
#
# ### GenAI Core Components and Architecture Overview
# ![AI core components and architecture](images/mlflow_gen_arch.png )

# %% [markdown]
# ---
# ## Step 2: Installation
#
# Install MLflow and the dependencies needed to work with LLMs.
#
# You can install with either `pip install -r requirements.txt` or `uv sync`. This series uses `uv`.
#
# See [README.md](./README.md) for the full `uv` setup instructions; the repository ships a `pyproject.toml` with the pinned dependencies.

# %%
# Verify installation
import mlflow
import openai
print(f"MLflow version: {mlflow.__version__}")
print(f"OpenAI version: {openai.__version__}")
# Out:
# MLflow version: 3.8.1
# OpenAI version: 2.14.0

# %% [markdown]
# ### Understanding MLflow Versions
#
# - **MLflow 3.x**: the latest release, with enhanced tracing and evaluation (recommended)
#
# You should see MLflow version 3.9.0 or higher printed above.

# %% [markdown]
# ---
# ## Step 3: Environment Configuration
#
# Configure your API keys and MLflow settings. We'll use a `.env` file for secure credential management.

# %%
# Create a .env file for your API keys (do this once)
# This file should NOT be committed to version control

import os
from pathlib import Path

env_file = Path(".env")

if not env_file.exists():
    print("Creating .env file...")
    with open(env_file, "w") as f:
        f.write("# MLflow GenAI Tutorial Configuration\n")
        f.write("OPENAI_API_KEY=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\n")
        f.write("\n# MLflow Configuration\n")
        f.write("MLFLOW_TRACKING_URI=http://localhost:5000\n")
    print("Confirmed -- Created .env file. Please edit it and add your OpenAI API or Model Provider keys and URLs.")
else:
    print("The .env file already exists.")
# Out:
# Creating .env file...
# Confirmed -- Created .env file. Please edit it and add your OpenAI API or Model Provider keys and URLs.

# %%
# Load environment variables
from dotenv import load_dotenv
import os

load_dotenv()

# Check if using Databricks AI Gateway
use_databricks_ai_gateway = os.getenv("USE_DATABRICKS_CLIENT") == "True"

if use_databricks_ai_gateway:
    print("Confirmed -- Using Databricks hosted foundational models via AI Gateway")
else:
    api_key = os.getenv("OPENAI_API_KEY")
    # Verify API key is set (without displaying it)
    if api_key and api_key != "your-api-key-here":
        print("Confirmed -- OpenAI API key is configured")
    else:
        print("ERROR -- Please set your OPENAI_API_KEY in the .env file")
# Out:
# Confirmed -- OpenAI API key is configured

# %% [markdown]
# ### Security Best Practice
#
# **Always use environment variables or secure credential managers for API keys!**
#
# Never hardcode credentials in your notebooks or commit them to version control.

# %% [markdown]
# ---
# ## Step 4: Starting the MLflow UI
#
# The MLflow UI is a web interface for visualizing and comparing experiments.
#
# ### To start the UI:
#
# **Option 1: From this notebook**
# ```python
# # This will block the cell - run in a separate terminal instead
# !mlflow ui --port 5000
# ```
#
# **Option 2: From terminal (recommended)**
# ```bash
# cd /path/to/this/directory
#
# mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000
#
# ```
#
# Then open your browser to: **http://localhost:5000**

# %% [markdown]
# ---
# ## Step 5: MLflow Tracking Setup
#
# MLflow stores experiment data in two places:
# 1. **Backend store**: metadata such as parameters, metrics, and tags (SQLite here)
# 2. **Artifact store**: files such as models, plots, logs, text, and images (filesystem here)
#
# For local development, we'll use SQLite for the backend store and the filesystem for artifacts.

# %%
# In Databricks, MLflow tracking is managed automatically
# Set to use Databricks managed tracking
mlflow.set_tracking_uri("databricks")
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
# Out:
# MLflow Tracking URI: databricks

# %%
# Create a test experiment
# Note: In Databricks, MLflow tracking is managed automatically
experiment_name = "/Users/adam.m.lang@gmail.com/01-setup-verification"
mlflow.set_experiment(experiment_name)

print(f"  Confirmed -- Created experiment: {experiment_name}")
print(f"   Experiment ID: {mlflow.get_experiment_by_name(experiment_name).experiment_id}")
# Out:
# 2026/09/09 20:27:17 INFO mlflow.tracking.fluent: Experiment with name '/Users/adam.m.lang@gmail.com/01-setup-verification' does not exist. Creating a new experiment.
#   Confirmed -- Created experiment: /Users/adam.m.lang@gmail.com/01-setup-verification
#    Experiment ID: 2334733235937707

# %% [markdown]
# ---
# ## Step 6: First MLflow Run
#
# Let's create your first MLflow run to verify everything is working!

# %%
import time

# Start a run
with mlflow.start_run(run_name="setup-test") as run:
    # Example of Log basic parameters
    mlflow.log_param("test_param", "hello-mlflow")
    mlflow.log_param("framework", "openai")
    
    # Example of Log metrics
    mlflow.log_metric("setup_success", 1.0)
    mlflow.log_metric("timestamp", time.time())
    
    # Example of Log a text artifact (file)
    mlflow.log_text("MLflow GenAI Tutorial - Setup Complete!", "welcome.txt")
    
    print("  Confirmed -- Run completed successfully!")
    print(f"   Run ID: {run.info.run_id}")
    print(f"   Experiment ID: {run.info.experiment_id}")
# Out:
#   Confirmed -- Run completed successfully!
#    Run ID: 7195fa43152d4486ac6d5e980b405c36
#    Experiment ID: 2334733235937707

# %% [markdown]
# ### Setup complete
#
# At this point you've:
# - Installed MLflow
# - Configured your environment
# - Created an experiment
# - Logged your first run
#
# The data is now stored in the `mlflow.db` SQLite database file.

# %%
# Display instructions for starting the UI
print("""
╔══════════════════════════════════════════════════════════╗
║         MLflow UI - Getting Started                     ║
╚══════════════════════════════════════════════════════════╝

To start the MLflow UI, open a NEW terminal and run:

    cd {}
    mlflow ui --port 5000

Then open your browser to:

    http://localhost:5000

You should see:
  📊 Your experiments listed on the left
  🔍 Runs with parameters and metrics
  📈 Visualization capabilities

Keep the terminal running while using the UI.
Press Ctrl+C in the terminal to stop the UI server.
""".format(Path.cwd()))
# Out:
# ╔══════════════════════════════════════════════════════════╗
# ║         MLflow UI - Getting Started                     ║
# ╚══════════════════════════════════════════════════════════╝
#
# To start the MLflow UI, open a NEW terminal and run:
#
#     cd /Workspace/Users/adam.m.lang@gmail.com/MLflow_GenAI_observability
#     mlflow ui --port 5000
#
# Then open your browser to:
#
#     http://localhost:5000
#
# You should see:
#   📊 Your experiments listed on the left
#   🔍 Runs with parameters and metrics
#   📈 Visualization capabilities
#
# Keep the terminal running while using the UI.
# Press Ctrl+C in the terminal to stop the UI server.

# %% [markdown]
# ---
# ## Step 7: Exploring the MLflow UI
#
# Once you have the UI running, explore these sections:
#
# ### 1. Experiments View
# - Lists all your experiments
# - Shows experiment metadata and tags
# - Search and filter capabilities
#
# ### 2. Runs View
# - Table of all runs in an experiment
# - Columns: parameters, metrics, tags, artifacts
# - Compare multiple runs
# - Search and filter runs
#
# ### 3. Run Details
# - Complete information about a single run
# - Parameters, metrics, tags
# - Artifacts browser
# - Model information
#
# ### 4. Traces Tab
# - Visualize LLM execution traces
# - Timeline view of spans
# - Input/output inspection
# - Performance analysis

# %% [markdown]
# ---
# ## Step 8: Verification Checklist
#
# Let's verify your setup is complete.

# %%
# Verification script
def verify_setup():
    checks = []
    
    # Check 1: MLflow installed
    try:
        import mlflow
        checks.append(("✅", "MLflow installed", mlflow.__version__))
    except ImportError:
        checks.append(("❌", "MLflow not installed", "N/A"))
    
    # Check 2: OpenAI installed
    try:
        import openai
        checks.append(("✅", "OpenAI SDK installed", openai.__version__))
    except ImportError:
        checks.append(("❌", "OpenAI SDK not installed", "N/A"))
    
    # Check 3: API key configured
    use_databricks = os.getenv("USE_DATABRICKS_CLIENT") == "True"
    if use_databricks:
        print("✅ Using Databricks Workspace and Databricks profile")
        print("✅ Using Databricks hosted foundational models")
        print("✅ Using Databricks workspace client")
    else:
        api_key = os.getenv("OPENAI_API_KEY")
        if api_key and api_key != "your-api-key-here":
            checks.append(("✅", "OpenAI API key configured", "***"))
        else:
            checks.append(("❌", "OpenAI API key not configured", "N/A"))
    
    # Check 4: Tracking URI set
    tracking_uri = mlflow.get_tracking_uri()
    checks.append(("✅", "Tracking URI set", tracking_uri))
    
    # Check 5: Test experiment exists
    try:
        exp = mlflow.get_experiment_by_name("01-setup-verification")
        if exp:
            checks.append(("✅", "Test experiment created", exp.experiment_id))
        else:
            checks.append(("❌", "Test experiment not found", "N/A"))
    except Exception as e:
        checks.append(("❌", "Test experiment not found", str(e)))
    
    
    # Print results
    print("\n" + "="*60)
    print("       SETUP VERIFICATION RESULTS")
    print("="*60 + "\n")
    
    for status, check, detail in checks:
        print(f"{status} {check:.<40} {detail}")
    
    print("\n" + "="*60)
    
    # Overall status
    if all(status == "✅" for status, _, _ in checks):
        print("\n🎉 Setup complete! You're ready to proceed to the next notebook.")
    else:
        print("\n⚠️  Some checks failed. Please review the errors above.")

verify_setup()
# Out:
# ============================================================
#        SETUP VERIFICATION RESULTS
# ============================================================
#
# ✅ MLflow installed........................ 3.8.1
# ✅ OpenAI SDK installed.................... 2.14.0
# ✅ OpenAI API key configured............... ***
# ✅ Tracking URI set........................ databricks
# ❌ Test experiment not found............... N/A
#
# ============================================================
#
# ⚠️  Some checks failed. Please review the errors above.

# %% [markdown]
# ---
# ## Step 9: Quick Reference - Common Commands
#
# Here are some common MLflow commands you'll use throughout the tutorials:

# %%
# Quick reference guide
print("""
╔══════════════════════════════════════════════════════════════╗
║           MLflow Quick Reference Guide                       ║
╚══════════════════════════════════════════════════════════════╝

📊 EXPERIMENTS
  mlflow.set_experiment("experiment-name")
  mlflow.get_experiment_by_name("experiment-name")
  mlflow.list_experiments()

🏃 RUNS
  with mlflow.start_run(run_name="my-run"):
      # Your code here
      pass

📝 LOGGING
  mlflow.log_param("key", "value")              # Single value
  mlflow.log_params({"key1": "val1", ...})      # Multiple values
  mlflow.log_metric("accuracy", 0.95)           # Single metric
  mlflow.log_metrics({"acc": 0.95, ...})        # Multiple metrics
  mlflow.log_text(text, "file.txt")             # Text artifact
  mlflow.log_artifact("path/to/file")           # File artifact

🔍 TRACING (GenAI)
  mlflow.openai.autolog()                       # Auto-trace OpenAI
  mlflow.langchain.autolog()                    # Auto-trace LangChain
  @mlflow.trace                                 # Manual tracing decorator

🖥️  UI COMMANDS
  mlflow ui                                     # Start UI (port 5000)
  mlflow ui --port 8080                         # Custom port
  mlflow ui --backend-store-uri                 # Custom backend
  mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000

🔧 CONFIGURATION
  mlflow.set_tracking_uri("uri")                # Set tracking location
  mlflow.get_tracking_uri()                     # Get current URI
  mlflow.set_registry_uri("uri")                # Set model registry

""")
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║           MLflow Quick Reference Guide                       ║
# ╚══════════════════════════════════════════════════════════════╝
#
# 📊 EXPERIMENTS
#   mlflow.set_experiment("experiment-name")
#   mlflow.get_experiment_by_name("experiment-name")
#   mlflow.list_experiments()
#
# 🏃 RUNS
#   with mlflow.start_run(run_name="my-run"):
#       # Your code here
#       pass
#
# 📝 LOGGING
#   mlflow.log_param("key", "value")              # Single value
#   mlflow.log_params({"key1": "val1", ...})      # Multiple values
#   mlflow.log_metric("accuracy", 0.95)           # Single metric
#   mlflow.log_metrics({"acc": 0.95, ...})        # Multiple metrics
#   mlflow.log_text(text, "file.txt")             # Text artifact
#   mlflow.log_artifact("path/to/file")           # File artifact
#
# 🔍 TRACING (GenAI)
#   mlflow.openai.autolog()                       # Auto-trace OpenAI
#   mlflow.langchain.autolog()                    # Auto-trace LangChain
#   @mlflow.trace                                 # Manual tracing decorator
#
# 🖥️  UI COMMANDS
#   mlflow ui                                     # Start UI (port 5000)
#   mlflow ui --port 8080                         # Custom port
#   mlflow ui --backend-store-uri                 # Custom backend
#   mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000
#
# 🔧 CONFIGURATION
#   mlflow.set_tracking_uri("uri")                # Set tracking location
#   mlflow.get_tracking_uri()                     # Get current URI
#   mlflow.set_registry_uri("uri")                # Set model registry

# %% [markdown]
# ---
# ## Summary
#
# In this notebook, you:
#
# 1. Learned what MLflow is and why it's useful for GenAI
# 2. Reviewed the MLflow architecture and core components
# 3. Installed MLflow and the required dependencies
# 4. Configured your environment with API keys
# 5. Set up MLflow tracking
# 6. Created your first experiment and run
# 7. Started the MLflow UI
# 8. Verified your setup
#
# ### Next Steps
#
# Next up:
#
# **Notebook 1.2: Experiment Tracking for LLMs**
# - Track LLM experiments
# - Log parameters, metrics, and artifacts
# - Compare different LLM configurations
# - Organize your GenAI experiments
#
# ### Resources
#
# - [MLflow Documentation](https://mlflow.org/docs/latest/)
# - [MLflow GenAI Guide](https://mlflow.org/docs/latest/genai/)
# - [MLflow Community Slack](https://mlflow.org/community/)
# - [MLflow GitHub](https://github.com/mlflow/mlflow)
